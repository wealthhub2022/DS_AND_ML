# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill']) # kernel density estimate(KDE)
# Out:
# C:\Users\23480\AppData\Local\Temp\ipykernel_6628\4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'], kde=False)
# Out:
# C:\Users\23480\AppData\Local\Temp\ipykernel_6628\2337428669.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], kde=False)
# <Axes: xlabel='total_bill'>

# %%
# changing the umbers of bins

# %%
sns.distplot(tips['total_bill'], kde=False,bins=20)
# Out:
# C:\Users\23480\AppData\Local\Temp\ipykernel_6628\2010981083.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], kde=False,bins=20)
# <Axes: xlabel='total_bill'>

# %%
#Joint Plot

# %%
sns.jointplot(x='total_bill',y="tip",data=tips)

# %%
sns.jointplot(x='total_bill',y="tip",data=tips, kind='hex')

# %%
sns.jointplot(x='total_bill',y="tip",data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill',y="tip",data=tips, kind='kde')

# %%
# Pairplot: this plots parallel relationships across the dataframe

# %%
sns.pairplot(tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips, hue='sex') # hue is used to pass categorical-not numrical or continus but categorical
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(tips, hue='sex',palette='coolwarm')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.rugplot(tips['total_bill']) #univariate variable
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\23480\AppData\Local\Temp\ipykernel_6628\4271412032.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False)
# Out:
# C:\Users\23480\AppData\Local\Temp\ipykernel_6628\1163654811.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'],kde=False)
# <Axes: xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'],kde=False)

# %%
import numpy as np
import matplotlib.pyplot as plt 
from scipy import stats

# %%
#Create dataset
df = np.random.randn(25)

# Create another rugplot
sns.rugplot(df)

# Set up the x-axis for the plot
x_min = df.min() - 2
x_max = df.max() + 2

# 200 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max, 100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/kernel_density_estimation#Practical_estimation_of_the_bandwidth'
bandwidth = ((4*df.std()**5)/(3*len(df)))**.2

# create an empty kernel list
kernel_list = []

# plot each basis function
for data_point in  df:
    #   creat a kernal for each point and append to list
    kernel = stats.norm(data_point, bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
#     scal for ploting
kernel = kernel/kernel.max()
kernel = kernel*.4
plt.plot(x_axis,kernel,color='grey',alpha=0.5)
plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# Sum the basis funtions

# %%
# Plting the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plt figure
fig = plt.plot(x_axis, sum_of_kde, color='indianred')

# Add the initial rugplot
sns.rugplot(df, c='indianred')

# Get rid of y-tick marks
plt.yticks([])
plt.suptitle('Sum of the Basis Function')
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Function')
