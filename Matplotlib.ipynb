# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_1 =np.random.random(60)*100
data_2 =np.random.random(60)*100
data_2
# Out:
# array([82.78160916,  4.82363873, 49.16901249, 91.58550498, 37.9694192 ,
#        25.25957096, 12.02706512, 24.87296568, 23.73063975, 88.60538996,
#        69.9510554 ,  9.98691556, 93.38786034, 29.52209901, 46.42075   ,
#        73.04269365,  8.56652737, 52.7532061 , 61.43420593, 93.91860158,
#        42.01818525, 69.32471993, 38.77916242, 77.85131854, 40.80042328,
#        56.32068893,  0.49180119, 18.91585593, 46.90568607, 33.67979726,
#         2.89704117, 28.8170784 , 13.20490364, 24.85997359, 54.72977241,
#         5.75441266, 18.3794663 , 45.95744113, 65.27386222, 65.6182824 ,
#         2.81557148, 75.63675329, 81.09457338, 22.81493183, 70.91867857,
#        30.57033266, 39.55914812, 14.46703224, 79.93721633, 21.47776318,
#        17.5702286 , 43.82101309, 20.01781267, 48.66238364, 83.80683553,
#         1.44868903, 82.76237669, 29.75556028, 65.41661427, 64.457901  ])

# %%
plt.scatter(data_1, data_2)

# %%
plt.scatter(data_1, data_2, c='#fa2')

# %%
plt.scatter(data_1, data_2, c='#fa2', marker='*')

# %%
plt.scatter(data_1, data_2, c='#fa2', marker='*', s=120)

# %%
plt.scatter(data_1, data_2, c='#fa2', marker='*', s=150, alpha=.5)

# %%
# line Chart

# %%
years = [2016 + i for i in range(15)]
prices = [50,70,74,77,80,83,82,87,89,85,90,60,87,98,66]

plt.plot(years, prices)

# %%
plt.plot(years, prices, c='y')

# %%
plt.plot(years, prices, c='y', lw=10)

# %%
plt.plot(years, prices, c='y', lw=10, linestyle=':')

# %%
plt.plot(years, prices, 'y--', lw=3)

# %%
course = ['django','CSS','JS','Python','PHP','Java','Go']
votes= [30,50,58,70,20,40,46]

plt.bar(course, votes)
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(course, votes, color='yellow')
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(course, votes, color='blue', align='edge')
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(course, votes, color='blue', align='edge', width=0.5, edgecolor='red')
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(course, votes, color='blue', align='edge', width=0.5, edgecolor='red', lw=5)
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# # Histogram

# %%
ages = np.random.normal(20,1.5, 1000)
ages
# Out:
# array([17.18884715, 20.38333077, 21.54840974, 21.83705469, 22.61706927,
#        17.29298345, 19.40369933, 21.19403137, 21.07462562, 15.6989381 ,
#        22.85753033, 20.16882754, 19.45429845, 19.3176687 , 22.32825863,
#        22.57812871, 19.89255089, 20.81666484, 20.44340539, 19.02699478,
#        22.18266667, 20.97044257, 19.60061534, 19.91070886, 19.10847088,
#        18.46202251, 21.79516571, 18.30872555, 19.70591   , 20.25562694,
#        17.51657511, 19.23963358, 21.19126611, 18.44878455, 20.80311264,
#        20.73550941, 21.68109065, 18.68157107, 22.2992471 , 19.48693071,
#        19.96270261, 19.78220253, 20.11525538, 19.9074949 , 22.73193382,
#        18.88624814, 21.53356484, 19.65031266, 18.28918405, 21.09733419,
#        19.74213225, 18.23710635, 20.02708313, 18.98397906, 21.20935686,
#        18.51061311, 20.80807922, 19.05560226, 21.06742542, 20.23061015,
#        20.64769054, 19.68673606, 21.60289593, 21.80595233, 18.20965125,
# ...

# %%
plt.hist(ages)
# Out:
# (array([  5.,  13.,  59., 146., 270., 241., 165.,  78.,  20.,   3.]),
#  array([14.81899859, 15.82754661, 16.83609463, 17.84464264, 18.85319066,
#         19.86173867, 20.87028669, 21.87883471, 22.88738272, 23.89593074,
#         24.90447875]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(ages, bins=20)
# Out:
# (array([  1.,   4.,   1.,  12.,  23.,  36.,  68.,  78., 124., 146., 121.,
#         120., 111.,  54.,  54.,  24.,  10.,  10.,   1.,   2.]),
#  array([14.81899859, 15.3232726 , 15.82754661, 16.33182062, 16.83609463,
#         17.34036863, 17.84464264, 18.34891665, 18.85319066, 19.35746467,
#         19.86173867, 20.36601268, 20.87028669, 21.3745607 , 21.87883471,
#         22.38310871, 22.88738272, 23.39165673, 23.89593074, 24.40020475,
#         24.90447875]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(ages, bins=[ages.min(), 18,22, ages.max()])
# Out:
# (array([ 97., 811.,  92.]),
#  array([14.81899859, 18.        , 22.        , 24.90447875]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(ages, cumulative=True)
# Out:
# (array([   5.,   18.,   77.,  223.,  493.,  734.,  899.,  977.,  997.,
#         1000.]),
#  array([14.81899859, 15.82754661, 16.83609463, 17.84464264, 18.85319066,
#         19.86173867, 20.87028669, 21.87883471, 22.88738272, 23.89593074,
#         24.90447875]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Pie Chart

# %%
course = ['django','CSS','JS','Python','PHP','Java','Go']
votes= [30,50,58,70,20,40,46]
explodes = [0.3,0,0,0,0,0,0]

# %%
plt.pie(votes,labels=course)
# Out:
# ([<matplotlib.patches.Wedge at 0x20a300cac50>,
# ...
#  [Text(1.0508206600117689, 0.3252321332409061, 'django'),
#   Text(0.4984086795462452, 0.9806063369940908, 'CSS'),
#   Text(-0.630433165019814, 0.9014177857370578, 'JS'),
#   Text(-1.04410276571934, -0.3461927420054109, 'Python'),
#   Text(-0.37737095353290917, -1.0332430321224833, 'PHP'),
#   Text(0.2722795795755731, -1.0657691262868096, 'Java'),
#   Text(0.9855438233192093, -0.4885727912167801, 'Go')])

# %%
plt.pie(votes,labels=course, explode=explodes)
# Out:
# ([<matplotlib.patches.Wedge at 0x20a3021e290>,
# ...
#  [Text(1.3374081127422512, 0.4139318059429714, 'django'),
#   Text(0.4984086795462452, 0.9806063369940908, 'CSS'),
#   Text(-0.630433165019814, 0.9014177857370578, 'JS'),
#   Text(-1.04410276571934, -0.3461927420054109, 'Python'),
#   Text(-0.37737095353290917, -1.0332430321224833, 'PHP'),
#   Text(0.2722795795755731, -1.0657691262868096, 'Java'),
#   Text(0.9855438233192093, -0.4885727912167801, 'Go')])

# %%
plt.pie(votes,labels=course, explode=explodes, autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x20a30281d90>,
# ...
#  [Text(1.3374081127422512, 0.4139318059429714, 'django'),
#   Text(0.4984086795462452, 0.9806063369940908, 'CSS'),
#   Text(-0.630433165019814, 0.9014177857370578, 'JS'),
#   Text(-1.04410276571934, -0.3461927420054109, 'Python'),
#   Text(-0.37737095353290917, -1.0332430321224833, 'PHP'),
#   Text(0.2722795795755731, -1.0657691262868096, 'Java'),
#   Text(0.9855438233192093, -0.4885727912167801, 'Go')],
#  [Text(0.8597623581914473, 0.2660990181061959, '9.55%'),
#   Text(0.27185927975249735, 0.5348761838149586, '15.92%'),
#   Text(-0.343872635465353, 0.4916824285838496, '18.47%'),
#   Text(-0.5695105994832763, -0.18883240473022408, '22.29%'),
#   Text(-0.20583870192704135, -0.5635871084304453, '6.37%'),
#   Text(0.14851613431394894, -0.5813286143382597, '12.74%'),
#   Text(0.5375693581741141, -0.2664942497546073, '14.65%')])

# %%
plt.pie(votes,labels=course, explode=explodes, autopct="%.2f%%", pctdistance=.8)
# Out:
# ([<matplotlib.patches.Wedge at 0x20a314a41d0>,
# ...
#  [Text(1.3374081127422512, 0.4139318059429714, 'django'),
#   Text(0.4984086795462452, 0.9806063369940908, 'CSS'),
#   Text(-0.630433165019814, 0.9014177857370578, 'JS'),
#   Text(-1.04410276571934, -0.3461927420054109, 'Python'),
#   Text(-0.37737095353290917, -1.0332430321224833, 'PHP'),
#   Text(0.2722795795755731, -1.0657691262868096, 'Java'),
#   Text(0.9855438233192093, -0.4885727912167801, 'Go')],
#  [Text(1.0508206600117689, 0.3252321332409061, '9.55%'),
#   Text(0.3624790396699965, 0.7131682450866115, '15.92%'),
#   Text(-0.4584968472871374, 0.6555765714451329, '18.47%'),
#   Text(-0.7593474659777019, -0.25177653964029884, '22.29%'),
#   Text(-0.2744516025693885, -0.7514494779072606, '6.37%'),
#   Text(0.1980215124185986, -0.7751048191176797, '12.74%'),
#   Text(0.7167591442321521, -0.35532566633947643, '14.65%')])

# %%
plt.pie(votes,labels=course, explode=explodes, autopct="%.2f%%", pctdistance=.8, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x20a314d7190>,
# ...
#  [Text(-0.4139318059429712, 1.3374081127422512, 'django'),
#   Text(-0.9806063369940908, 0.4984086795462453, 'CSS'),
#   Text(-0.9014177857370578, -0.630433165019814, 'JS'),
#   Text(0.34619274200541084, -1.04410276571934, 'Python'),
#   Text(1.0332430321224833, -0.3773709535329092, 'PHP'),
#   Text(1.0657691262868096, 0.272279579575573, 'Java'),
#   Text(0.48857279121678016, 0.9855438233192093, 'Go')],
#  [Text(-0.32523213324090594, 1.0508206600117689, '9.55%'),
#   Text(-0.7131682450866115, 0.36247903966999656, '15.92%'),
#   Text(-0.6555765714451329, -0.4584968472871374, '18.47%'),
#   Text(0.2517765396402988, -0.7593474659777019, '22.29%'),
#   Text(0.7514494779072606, -0.27445160256938855, '6.37%'),
#   Text(0.7751048191176797, 0.19802151241859856, '12.74%'),
#   Text(0.3553256663394765, 0.7167591442321521, '14.65%')])

# %%
#box

# %%
heights=np.random.normal(172,8,300)
plt.boxplot(heights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20a31851910>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20a318ae210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20a3187da50>],
#  'medians': [<matplotlib.lines.Line2D at 0x20a318af7d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20a318ae710>],
#  'means': []}

# %%
years =[2014,2015,2016,2017,2018,2019,2020,2021,2022]
income = [55,56,57,60,62,67,73,77,79]

income_ticks = list(range(60,85,3))

# %%
plt.plot(years, income)

# %%
plt.plot(years, income)
plt.title('Income of John Doe(in Naira)')
# Out:
# Text(0.5, 1.0, 'Income of John Doe(in Naira)')

# %%
plt.plot(years, income)
plt.title('Income of John Doe(in Naira)')
plt.xlabel('Year')
plt.ylabel('Yearly Income In Naira')
# Out:
# Text(0, 0.5, 'Yearly Income In Naira')

# %%
plt.plot(years, income)
plt.title('Income of John Doe(in Naira)', fontsize=20, fontname='Algerian')
plt.xlabel('Year')
plt.ylabel('Yearly Income In Naira')
plt.yticks(income_ticks, [f"N{i}k" for i in income_ticks])
# Out:
# ([<matplotlib.axis.YTick at 0x20a31f2d710>,
# ...
#  [Text(0, 60, 'N60k'),
#   Text(0, 63, 'N63k'),
#   Text(0, 66, 'N66k'),
#   Text(0, 69, 'N69k'),
#   Text(0, 72, 'N72k'),
#   Text(0, 75, 'N75k'),
#   Text(0, 78, 'N78k'),
#   Text(0, 81, 'N81k'),
#   Text(0, 84, 'N84k')])

# %%
plt.plot(years, income)
plt.title('Income of John Doe(in Naira)', fontsize=20, fontname='Algerian')
plt.xlabel('Year', fontsize=10, fontname='Algerian')
plt.ylabel('Yearly Income In Naira')
plt.yticks(income_ticks, [f"N{i}k" for i in income_ticks])
# Out:
# ([<matplotlib.axis.YTick at 0x20a31f8fc10>,
# ...
#  [Text(0, 60, 'N60k'),
#   Text(0, 63, 'N63k'),
#   Text(0, 66, 'N66k'),
#   Text(0, 69, 'N69k'),
#   Text(0, 72, 'N72k'),
#   Text(0, 75, 'N75k'),
#   Text(0, 78, 'N78k'),
#   Text(0, 81, 'N81k'),
#   Text(0, 84, 'N84k')])

# %% [markdown]
# # Adding Legend

# %%
company1 = [100,103,99,105,101,102]
company2 = [90,95,102,104,160,109,103]
company3 = [110,116,100,104,98,95]
company4 = [102,1190,100,90,78,100]

# %%
plt.plot(company1)
plt.plot(company2)
plt.plot(company3)

# %%
plt.plot(company1, label='MTN')
plt.plot(company2, label='GLO')
plt.plot(company3, label='9MOBILE')
plt.legend()

# %%
plt.plot(company1, label='MTN')
plt.plot(company2, label='GLO')
plt.plot(company3, label='9MOBILE')
plt.legend(loc='upper left')

# %%
plt.tight_layout()
plt.savefig('lineplots_23.png', dpi=100, transparent=False, bbox_inches='tight' )

# %%
votes = [10,12,5,15,22]
people = ['A','B','C','D','E']

plt.pie(votes,labels=None)
plt.legend(labels=people,)
# plt.legend(loc='lower right')

# %%
from matplotlib import style

style.use('ggplot')
votes = [10,12,5,15,22]
people = ['A','B','C','D','E']

plt.pie(votes,labels=None)
plt.legend(labels=people,)
# plt.legend(loc='lower right')

# %%
# style.use('dark_background')
votes = [10,12,5,15,22]
people = ['A','B','C','D','E']

plt.pie(votes,labels=None)
plt.legend(labels=people,)

# %% [markdown]
# # Plotinting Group

# %%
x1, y1 =np.random.random(100), np.random.random(100)
x2, y2 = np.arange(100), np.random.random(100)

plt.figure(1)
plt.scatter(x1, y1)
plt.figure(2)
plt.plot(x2,y2)

# %%
x = np.arange(100)
fig, axs = plt.subplots(2,2)
axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title('Sine Wave')

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title('Cosine Wave')


axs[1,0].plot(x, np.random.random(100))
axs[1,0].set_title('Random Function')

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title('Log Function')
axs[1,1].set_xlabel('TESTING')
# Out:
# C:\Users\23480\AppData\Local\Temp\ipykernel_10924\3793174036.py:13: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))
# Text(0.5, 0, 'TESTING')

# %%
x = np.arange(100)
fig, axs = plt.subplots(2,2)
axs[0,0].plot(x, np.sin(x))
axs[0,0].set_title('Sine Wave')

axs[0,1].plot(x, np.cos(x))
axs[0,1].set_title('Cosine Wave')


axs[1,0].plot(x, np.random.random(100))
axs[1,0].set_title('Random Function')

axs[1,1].plot(x, np.log(x))
axs[1,1].set_title('Log Function')

fig.suptitle('Four Plots')
# Out:
# C:\Users\23480\AppData\Local\Temp\ipykernel_10924\1592965235.py:13: RuntimeWarning: divide by zero encountered in log
#   axs[1,1].plot(x, np.log(x))
# Text(0.5, 0.98, 'Four Plots')

# %%
plt.savefig('fourplots_2.png', dpi=100, transparent=True)

# %%
plt.tight_layout()
plt.savefig('fourplots_23.png', dpi=100, transparent=False, bbox_inches='tight', )

# %% [markdown]
# # 3D

# %%
ax = plt.axes(projection='3d')
a = np.random.random(100)
b = np.random.random(100)
c = np.random.random(100)

ax.scatter(a,b,c)
ax.set_title('3D Plot')
# Out:
# Text(0.5, 0.92, '3D Plot')

# %%
ax = plt.axes(projection='3d')
a = np.arange(0,50,0.1)
b = np.sin(a)
c = np.cos(a)

ax.scatter(a,b,c)
ax.set_title('3D Plot')
# Out:
# Text(0.5, 0.92, '3D Plot')

# %%
ax = plt.axes(projection='3d')
a = np.arange(0,50,0.1)
b = np.arange(0,50,0.1)
c = np.cos(a+b)

ax.scatter(a,b,c)
ax.set_title('3D Plot')
# Out:
# Text(0.5, 0.92, '3D Plot')

# %%
ax = plt.axes(projection='3d')
x = np.arange(-6,6,0.1)
x = np.arange(-6,6,0.1)
X , Y = np.meshgrid(X+Y)

Z = np.sin(X)*no.cos(Y)

ax.plot_surface(X,Y,Z)
ax.set_title('3D Plot')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[132], line 4
#       2 x = np.arange(-6,6,0.1)
#       3 x = np.arange(-6,6,0.1)
# ----> 4 X , Y = np.meshgrid(X+Y)
#       6 Z = np.sin(X)*no.cos(Y)
#       8 ax.plot_surface(X,Y,Z)
#
# NameError: name 'X' is not defined
