# %% [markdown]
# # loadin data into Pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.show()

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# # Reading Data in pandas

# %%
## Read Headers
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# # Read each column

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df['Name'][0:5]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
df.Name[0:7]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# 5               Charmeleon
# 6                Charizard
# Name: Name, dtype: object

# %%
df[['Name','Type 1', 'Type 2', 'HP']]
# Out:
#                       Name   Type 1  Type 2  HP
# 0                Bulbasaur    Grass  Poison  45
# 1                  Ivysaur    Grass  Poison  60
# 2                 Venusaur    Grass  Poison  80
# 3    VenusaurMega Venusaur    Grass  Poison  80
# 4               Charmander     Fire     NaN  39
# ..                     ...      ...     ...  ..
# 795                Diancie     Rock   Fairy  50
# 796    DiancieMega Diancie     Rock   Fairy  50
# 797    HoopaHoopa Confined  Psychic   Ghost  80
# 798     HoopaHoopa Unbound  Psychic    Dark  80
# 799              Volcanion     Fire   Water  80
#
# [800 rows x 4 columns]

# %% [markdown]
# # Read Each Row

# %%
df.iloc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
df.iloc[1:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
for x, y in df.iterrows():
    print(x, y)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
for index, row in df.iterrows():
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
df.loc[df['Type 1']=='Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
df.loc[df['Type 1']=='Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df['Type 1']=='Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # Read a specific location

# %%
df.iloc[2,1]
# Out:
# 'Venusaur'

# %% [markdown]
# # Sorting/Desribing Data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'])
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending=True)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending=False)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 351  321    Wailord  Water     NaN  170      90       45       90       45
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', 'HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making changes to the data

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df = df.drop(columns=['Total'])

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df['Total'] = df.iloc[:, 4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
cols = list(df.columns)
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Speed  Generation  Legendary  \
# 0  1              Bulbasaur  Grass  Poison     45           1      False
# 1  2                Ivysaur  Grass  Poison     60           1      False
# 2  3               Venusaur  Grass  Poison     80           1      False
# 3  3  VenusaurMega Venusaur  Grass  Poison     80           1      False
# 4  4             Charmander   Fire     NaN     65           1      False
#
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0    318  45      49       49       65       65
# 1    405  60      62       63       80       80
# 2    525  80      82       83      100      100
# 3    625  80     100      123      122      120
# 4    309  39      52       43       60       50

# %% [markdown]
# # Saving our Data (Exporting into desired fFormat)

# %%
df.to_csv('modified.csv')

# %%
df.to_csv('modified_2.csv', index=False)

# %%
df.to_excel('modified_3.xlsx', index=False)

# %%
df.to_csv('modified_3.txt', index=False, sep='\t')

# %% [markdown]
# # Filtring Data

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2  Speed  Generation  \
# 0      1              Bulbasaur  Grass    Poison     45           1
# 1      2                Ivysaur  Grass    Poison     60           1
# 2      3               Venusaur  Grass    Poison     80           1
# 3      3  VenusaurMega Venusaur  Grass    Poison     80           1
# 48    43                 Oddish  Grass    Poison     30           1
# ..   ...                    ...    ...       ...    ...         ...
# 718  650                Chespin  Grass       NaN     38           6
# 719  651              Quilladin  Grass       NaN     57           6
# 720  652             Chesnaught  Grass  Fighting     64           6
# 740  672                 Skiddo  Grass       NaN     52           6
# 741  673                 Gogoat  Grass       NaN     68           6
#
#      Legendary  Total   HP  Attack  Defense  Sp. Atk  Sp. Def
# 0        False    318   45      49       49       65       65
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['HP']==45)]
# Out:
#        #       Name Type 1  Type 2  Speed  Generation  Legendary  Total  HP  \
# 0      1  Bulbasaur  Grass  Poison     45           1      False    318  45
# 48    43     Oddish  Grass  Poison     30           1      False    320  45
# 166  152  Chikorita  Grass     NaN     45           2      False    318  45
# 467  420    Cherubi  Grass     NaN     35           4      False    275  45
# 554  495      Snivy  Grass     NaN     63           5      False    308  45
# 608  548    Petilil  Grass     NaN     30           5      False    280  45
#
#      Attack  Defense  Sp. Atk  Sp. Def
# 0        49       49       65       65
# 48       50       55       75       65
# 166      49       65       49       65
# 467      35       45       62       53
# 554      45       55       45       55
# 608      35       50       70       50

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['HP']==45)]
# Out:
#        #       Name Type 1  Type 2  Speed  Generation  Legendary  Total  HP  \
# 0      1  Bulbasaur  Grass  Poison     45           1      False    318  45
# 48    43     Oddish  Grass  Poison     30           1      False    320  45
# 166  152  Chikorita  Grass     NaN     45           2      False    318  45
# 467  420    Cherubi  Grass     NaN     35           4      False    275  45
# 554  495      Snivy  Grass     NaN     63           5      False    308  45
# 608  548    Petilil  Grass     NaN     30           5      False    280  45
#
#      Attack  Defense  Sp. Atk  Sp. Def
# 0        49       49       65       65
# 48       50       55       75       65
# 166      49       65       49       65
# 467      35       45       62       53
# 554      45       55       45       55
# 608      35       50       70       50

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2']=='Poison') & (df['HP']>45)]

# %%
new_df.to_csv('new_file.csv', index=False)

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Speed  Generation  \
# 3      3      VenusaurMega Venusaur     Grass    Poison     80           1
# 7      6  CharizardMega Charizard X      Fire    Dragon    100           1
# 8      6  CharizardMega Charizard Y      Fire    Flying    100           1
# 12     9    BlastoiseMega Blastoise     Water       NaN     78           1
# 19    15      BeedrillMega Beedrill       Bug    Poison    145           1
# 23    18        PidgeotMega Pidgeot    Normal    Flying    121           1
# 71    65      AlakazamMega Alakazam   Psychic       NaN    150           1
# 87    80        SlowbroMega Slowbro     Water   Psychic     30           1
# 102   94          GengarMega Gengar     Ghost    Poison    130           1
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    100           1
# 137  127          PinsirMega Pinsir       Bug    Flying    105           1
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#        #                 Name   Type 1  Type 2  Speed  Generation  Legendary  \
# 0      1            Bulbasaur    Grass  Poison     45           1      False
# 1      2              Ivysaur    Grass  Poison     60           1      False
# 2      3             Venusaur    Grass  Poison     80           1      False
# 4      4           Charmander     Fire     NaN     65           1      False
# 5      5           Charmeleon     Fire     NaN     80           1      False
# ..   ...                  ...      ...     ...    ...         ...        ...
# 794  718     Zygarde50% Forme   Dragon  Ground     95           6       True
# 795  719              Diancie     Rock   Fairy     50           6       True
# 797  720  HoopaHoopa Confined  Psychic   Ghost     70           6       True
# 798  720   HoopaHoopa Unbound  Psychic    Dark     80           6       True
# 799  721            Volcanion     Fire   Water     70           6       True
#
# ...

# %%
df.plot()
# Out:
# <Axes: >

# %%
df['HP'].plot()
# Out:
# <Axes: >

# %%
df.plot.scatter(x="HP", y="Type 1", alpha=0.5)
# Out:
# <Axes: xlabel='HP', ylabel='Type 1'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|Grass',regex=True )]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df['Type 1'].str.contains('fire|grass',flags =re.I, regex=True )]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 4      4             Charmander   Fire     NaN   39      52       43       60
# ..   ...                    ...    ...     ...  ...     ...      ...      ...
# 735  667                 Litleo   Fire  Normal   62      50       58       73
# 736  668                 Pyroar   Fire  Normal   86      68       72      109
# 740  672                 Skiddo  Grass     NaN   66      65       48       62
# 741  673                 Gogoat  Grass     NaN  123     100       62       97
# 799  721              Volcanion   Fire   Water   80     110      120      130
#
# ...

# %%
df.loc[df['Type 1'].str.contains('as[a-z]*',flags =re.I, regex=True )]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # Conditinal Changes

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1']='Wuse'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Wuse     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Wuse   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Wuse', 'Type 1']='Fire'
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.loc[df['Type 1'] == 'Fire', 'Legendary']=True
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df = pd.read_csv('modified.csv')
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Speed  \
# 0             0    1              Bulbasaur    Grass  Poison     45
# 1             1    2                Ivysaur    Grass  Poison     60
# 2             2    3               Venusaur    Grass  Poison     80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison     80
# 4             4    4             Charmander     Fire     NaN     65
# ..          ...  ...                    ...      ...     ...    ...
# 795         795  719                Diancie     Rock   Fairy     50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    110
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost     70
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark     80
# 799         799  721              Volcanion     Fire   Water     70
#
#      Generation  Legendary  Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0             1      False    318  45      49       49       65       65
# ...

# %%
df.loc[(df['Total'])> 400, ['Generation','Legendary']]='TESTING'
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Speed  \
# 0             0    1              Bulbasaur    Grass  Poison     45
# 1             1    2                Ivysaur    Grass  Poison     60
# 2             2    3               Venusaur    Grass  Poison     80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison     80
# 4             4    4             Charmander     Fire     NaN     65
# ..          ...  ...                    ...      ...     ...    ...
# 795         795  719                Diancie     Rock   Fairy     50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    110
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost     70
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark     80
# 799         799  721              Volcanion     Fire   Water     70
#
#     Generation Legendary  Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0            1     False    318  45      49       49       65       65
# ...

# %%
df.loc[(df['Total'])> 400, ['Generation','Legendary']]=['TESTING 1','WORKING 1']
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Speed  \
# 0             0    1              Bulbasaur    Grass  Poison     45
# 1             1    2                Ivysaur    Grass  Poison     60
# 2             2    3               Venusaur    Grass  Poison     80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison     80
# 4             4    4             Charmander     Fire     NaN     65
# ..          ...  ...                    ...      ...     ...    ...
# 795         795  719                Diancie     Rock   Fairy     50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    110
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost     70
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark     80
# 799         799  721              Volcanion     Fire   Water     70
#
#     Generation  Legendary  Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0            1      False    318  45      49       49       65       65
# ...

# %%
df = pd.read_csv('modified.csv')
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Speed  \
# 0             0    1              Bulbasaur    Grass  Poison     45
# 1             1    2                Ivysaur    Grass  Poison     60
# 2             2    3               Venusaur    Grass  Poison     80
# 3             3    3  VenusaurMega Venusaur    Grass  Poison     80
# 4             4    4             Charmander     Fire     NaN     65
# ..          ...  ...                    ...      ...     ...    ...
# 795         795  719                Diancie     Rock   Fairy     50
# 796         796  719    DiancieMega Diancie     Rock   Fairy    110
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost     70
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark     80
# 799         799  721              Volcanion     Fire   Water     70
#
#      Generation  Legendary  Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0             1      False    318  45      49       49       65       65
# ...

# %% [markdown]
# # Aggregate Statistics(Groupby)

# %%
df = pd.read_csv('modified.csv')
df.groupby(['Type 1']).mean()
