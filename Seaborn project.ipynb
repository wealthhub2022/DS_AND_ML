# %%
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('student.csv')
df.head()
# Out:
#    gender ethnicity  parental_education         lunch test_preparation_course  \
# 0  female   group B   bachelor's degree      standard                    none
# 1  female   group C        some college      standard               completed
# 2  female   group B     master's degree      standard                    none
# 3    male   group A  associate's degree  free/reduced                    none
# 4    male   group C        some college      standard                    none
#
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
len(df)
# Out:
# 1000

# %%
df.tail()
# Out:
#      gender ethnicity parental_education         lunch  \
# 995  female   group E    master's degree      standard
# 996    male   group C        high school  free/reduced
# 997  female   group C        high school  free/reduced
# 998  female   group D       some college      standard
# 999  female   group D       some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
sns.countplot(data=df, x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data=df, x='ethnicity')
# Out:
# <Axes: xlabel='ethnicity', ylabel='count'>

# %%
sns.countplot(data=df, x='parental_education')
# Out:
# <Axes: xlabel='parental_education', ylabel='count'>

# %%
sns.countplot(data=df, x='parental_education')
plt.xticks(rotation=15)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, "bachelor's degree"),
#   Text(1, 0, 'some college'),
#   Text(2, 0, "master's degree"),
#   Text(3, 0, "associate's degree"),
#   Text(4, 0, 'high school'),
#   Text(5, 0, 'some high school')])

# %%
# gender distribution
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
# 1. pie chart, 2. counts for each label 3. label name for slice of the pie
name = df['gender'].value_counts().index.tolist()
name
# Out:
# ['female', 'male']

# %%
value = df['gender'].value_counts().tolist()
value
# Out:
# [518, 482]

# %%
fig = plt.figure(figsize=(5,5))
plt.pie(value, labels=name, autopct='%2.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x26e775db610>,
# ...
#  [Text(-0.06217041096298424, 1.0982417038160106, 'female'),
#   Text(0.06217041096298411, -1.0982417038160106, 'male')],
#  [Text(-0.033911133252536856, 0.5990409293541875, '51.80%'),
#   Text(0.033911133252536786, -0.5990409293541875, '48.20%')])

# %%
sns.catplot(data=df, x='lunch', y='math_score', kind='box')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(data=df, x='math_score', y='reading_score')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
sns.scatterplot(data=df, x='math_score', y='reading_score', hue='gender')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
df.head()
# Out:
#    gender ethnicity  parental_education         lunch test_preparation_course  \
# 0  female   group B   bachelor's degree      standard                    none
# 1  female   group C        some college      standard               completed
# 2  female   group B     master's degree      standard                    none
# 3    male   group A  associate's degree  free/reduced                    none
# 4    male   group C        some college      standard                    none
#
#    math_score  reading_score  writing_score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %%
sns.catplot(data=df, x='ethnicity', y='math_score', kind='box')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.histplot(data=df, x='math_score')
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
# Kernel density estimation

# %%
sns.histplot(data=df, x='math_score', kde=True)
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
sns.histplot(data=df, x='math_score', kde=True,hue='gender')
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
sns.histplot(data=df, x='math_score', kde=True,hue='gender', palette=['lightpink','blue'])
# Out:
# <Axes: xlabel='math_score', ylabel='Count'>

# %%
sns.catplot(data=df, x='ethnicity', y='math_score', kind='box')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.kdeplot(data=df, x='math_score', hue='ethnicity',common_norm=False)
# Out:
# <Axes: xlabel='math_score', ylabel='Density'>

# %%
sns.scatterplot(data=df, x='math_score',y='reading_score')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
sns.scatterplot(data=df, x='math_score',y='reading_score', hue='gender')
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>

# %%
sns.scatterplot(data=df, x='math_score',y='reading_score', hue='gender', palette=['lightpink','blue'])
# Out:
# <Axes: xlabel='math_score', ylabel='reading_score'>
